# %%
import requests

#al llamar el metodo get se obtiene un objeto response
response=requests.get("http://www.platzi.com/")
#info en jupiter response? codigo fuente en jupyter response??
#response??
#para saber que metodos se pueden usar para este objeto
print(dir(response))
print(response.status_code)
print(response.headers)
#obtener texto de respuesta
print(response.text)
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# 200
# {'Date': 'Mon, 02 Jan 2023 21:21:27 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'CF-Ray': '78368b60d9ab228d-MIA', 'Access-Control-Allow-Origin': '*', 'Age': '138010', 'Cache-Control': 'no-store', 'Expires': 'Tue, 02 Jan 2024 21:21:27 GMT', 'Set-Cookie': 'pac-hRur47GmYKfmFy=A; path=/; Expires=Wed Jun 08 2022 00:00:00 GMT+0000 (Coordinated Universal Time);', 'Strict-Transport-Security': 'max-age=15552000; includeSubDomains; preload', 'Vary': 'Accept-Encoding', 'CF-Cache-Status': 'HIT', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'X-Requested-With,content-type,X-CSRFToken', 'Access-Control-Allow-Methods': 'GET, POST', 'Expect-CT': 'max-age=0', 'Referrer-Policy': 'no-referrer', 'X-Content-Type-Options': 'nosniff', 'X-DNS-Prefetch-Control': 'off', 'X-Download-Options': 'noopen', 'X-Frame-Options': 'SAMEORIGIN', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-XSS-Protection': '0', 'Server': 'cloudflare', 'Content-Encoding': 'br'}
#
# <!DOCTYPE html>
# <html lang=es>
# <head>
# <meta charset="UTF-8">
# <title>Platzi: ‎Cursos Online Profesionales de Tecnología</title>
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <meta name="referrer" content="no-referrer-when-downgrade">
# <meta name="description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!">
# <meta name="theme-color" content="#15210B" />
# <meta property="fb:app_id" content="263680607075199" />
# <meta property="fb:admins" content="1030603473" />
# <meta property="og:description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!" />
# <meta property="og:title" content="Platzi: ‎Cursos Online Profesionales de Tecnología" />
# <meta property="og:type" content="website" />
# <meta property="og:url" content="https://platzi.com/inicio/" />
# <meta property="og:image" content="https://static.platzi.com/media/meta_tags/og/OG-platzi-Dic-2019.webp" />
# <meta property="og:site_name" content="https://platzi.com/inicio/" />
# <meta property="twitter:account_id" content="4503599630205252" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:site" content="@Platzi" />
# <meta name="twitter:title" content="Platzi: ‎Cursos Online Profesionales de Tecnología" />
# <meta name="twitter:description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!" />
# <meta name="twitter:creator" content="@Platzi" />
# <meta name="twitter:image" content="https://static.platzi.com/media/meta_tags/og/OG-platzi-Dic-2019.webp" />
# <meta name="twitter:domain" content="https://platzi.com/inicio/" />
# <meta name="p:domain_verify" content="7b60446823db932528d0528d4cb50e66" />
# <link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" />
# <link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png">
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" />
# <link rel="stylesheet" href="https://static.platzi.com/npm/@fortawesome/fontawesome-svg-core@1.2.28/styles.css" />
# <link data-chunk="components-NeverStop-NeverStop-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-Prizes-Prizes-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/5785.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-Testimonies-Testimonies-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/app-shared-Testimonies-Testimonies-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-Community-Community-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/4570.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-LearningExperience-LearningExperience-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/app-shared-LearningExperience-LearningExperience-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-LearningExperience-LearningExperience-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/1676.0fdd400ad06930539b2c.css">
# <link data-chunk="components-RecentLaunches-RecentLaunches-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-Schools-Schools-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-TrustedList-TrustedList-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/24.0fdd400ad06930539b2c.css">
# <link data-chunk="home-public-old" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/home-public-old.0fdd400ad06930539b2c.css">
# <link data-chunk="home-public-old" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/1052.0fdd400ad06930539b2c.css">
# <link data-chunk="home-public-old" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/5012.0fdd400ad06930539b2c.css">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/5914.08727fd04f3ce820f757.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/2736.121cb7b1d4dadc257b35.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/9006.d6b90665fa5bb14bf76e.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/2771.fa244f37004f7935ed35.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/4851.f415106c624c2d2697db.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/9264.5c5e475a48b5c5daae60.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/4514.99ed71f7aa9fcbbef26a.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/1904.9e7e3f9d4a21fc3cb296.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/3376.97be01db325b119bf204.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6066.9c482c6542891d25f689.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/7199.67f933942d6a46c00755.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6838.33d3972156d8d6d96f24.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/69.115d87bbf9e4c2738bac.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/437.5deed1f8984690a0d381.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6443.569b253c0f5aa6179b6f.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/3935.e0b0ccd8ee1da552619e.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/381.4ef24135b42d92ef85ca.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6059.86fe8a09fabd86c36a5f.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/3042.c26f041774ec5045a529.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/940.a9aa4c36abcecfb3ac50.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/8136.dad225d3457d26cb4ed4.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/8876.3587e32a1d8dbbb4d2d0.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/5175.c232666172c2c9227ad1.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/3272.b447fff4c2a9e0fcdc2b.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/1052.ac30de87f1a4c4ff15f8.js">
# <link data-chunk="home-public-old" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/home-public-old.903881f15b9cd73fe029.js">
# <link data-chunk="app-shared-TrustedList-TrustedList-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-shared-TrustedList-TrustedList-jsx.4dee1c24761c453c73e6.js">
# <link data-chunk="components-Schools-Schools-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.d5447e3c11674899c980.js">
# <link data-chunk="components-RecentLaunches-RecentLaunches-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.f1ccb29ab10614903053.js">
# <link data-chunk="app-shared-LearningExperience-LearningExperience-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-shared-LearningExperience-LearningExperience-jsx.a540d18ef680190a5759.js">
# <link data-chunk="app-shared-Community-Community-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-shared-Community-Community-jsx.3d3ac6a4825db1a75f83.js">
# <link data-chunk="app-shared-Testimonies-Testimonies-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/7370.6988550dc30c2b988a89.js">
# <link data-chunk="app-shared-Testimonies-Testimonies-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-shared-Testimonies-Testimonies-jsx.f1121ee9fe6078eebc84.js">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/9214.462d89b7ee3e119a9881.js">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/5785.647ab8b01d30fcddab14.js">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.1178d53caeadc5a002a6.js">
# <link data-chunk="components-Prizes-Prizes-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.72cd01445fdc5f3a2aa2.js">
# <link data-chunk="components-NeverStop-NeverStop-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/9928.919d23f94759053b8e90.js">
# <link data-chunk="components-NeverStop-NeverStop-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.918cf692b6d83fcf35ea.js">
# <link data-chunk="home-public-old" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/5012.0fdd400ad06930539b2c.css">
# <link data-chunk="home-public-old" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/1052.0fdd400ad06930539b2c.css">
# <link data-chunk="home-public-old" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/home-public-old.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-TrustedList-TrustedList-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/24.0fdd400ad06930539b2c.css">
# <link data-chunk="components-Schools-Schools-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-RecentLaunches-RecentLaunches-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-LearningExperience-LearningExperience-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/1676.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-LearningExperience-LearningExperience-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/app-shared-LearningExperience-LearningExperience-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-Community-Community-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/4570.0fdd400ad06930539b2c.css">
# <link data-chunk="app-shared-Testimonies-Testimonies-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/app-shared-Testimonies-Testimonies-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/5785.0fdd400ad06930539b2c.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-Prizes-Prizes-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.0fdd400ad06930539b2c.css">
# <link data-chunk="components-NeverStop-NeverStop-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.0fdd400ad06930539b2c.css">
# <link rel="canonical" href="https://platzi.com" />
# <link rel="alternate" hreflang="x-default" href="https://platzi.com">
# <link rel="alternate" hreflang="es" href="https://platzi.com">
# <link rel="alternate" hreflang="pt" href="https://platzi.com.br">
# <link rel="alternate" hreflang="en" href="https://courses.platzi.com">
#
# <script>
#         (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#         h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#         (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#         })(window,document.documentElement,'async-hide','dataLayer',4000,
#         {'GTM-MPT6TFW':true});
#     </script>
#
#
# <script>
#       (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-MPT6TFW');
#     </script>
#
# <script async src="https://static.platzi.com/ajax/libs/lazysizes/5.2.0/lazysizes.min.js"></script>
# <script type="application/ld+json">
#     {
#       "@context": "http://schema.org",
#       "@type": "BreadcrumbList",
#       "itemListElement":
#         [{
#           "@type": "ListItem",
#           "position": 1,
#           "item":
#             {
#               "@id": "https://platzi.com/",
#               "name": "🚀 Platzi: ‎Cursos Online Profesionales de Tecnología"
#             }
#           }]
#     }
#   </script>
# </head>
# <body>
#
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MPT6TFW"
#           height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
# <div id="home-public-old"><header id="Header-v2" class="Header-v2 Header-v2-content is-dark-header"><nav class="Nav-header"><div class="Logo"><div class="LogoHeader"><a href="/" class="LogoHeader-link"><div class="LogoHeader-container"><figure><img loading="lazy" src="https://static.platzi.com/media/platzi-isotipo@2x.png" alt="Platzi isotipo" height="25" /></figure><figure class="LogoHeader-name"><img loading="lazy" src="https://static.platzi.com/media/logotipo-platzi.png" alt="Platzi Logo" height="25" /></figure></div></a></div></div><div class="Explore"><button type="button" class="ExploreButton" data-trans="header_explore_exploreButton">Explorar<svg aria-hidden="true" focusable="false" data-prefix="fas" data-icon="chevron-down" class="svg-inline--fa fa-chevron-down " role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path fill="currentColor" d="M233.4 406.6c12.5 12.5 32.8 12.5 45.3 0l192-192c12.5-12.5 12.5-32.8 0-45.3s-32.8-12.5-45.3 0L256 338.7 86.6 169.4c-12.5-12.5-32.8-12.5-45.3 0s-12.5 32.8 0 45.3l192 192z"></path></svg></button><div class="ExploreMenu" style="display:none"><div class="ExploreMenu-content" tabindex="1" style="margin-left:195px"><div class="ExploreMenu-categories"><p class="ExploreMenu-title" data-trans="header_explore_exploreMenu_category">Categorías</p><ul><li data-testid="category-item"><span><svg aria-hidden="true" focusable="false" data-prefix="far" data-icon="code" class="svg-inline--fa fa-code " role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 640 512" style="color:#17871D"><path fill="currentColor" d="M414.9 31.11L270.9 495.1C266.1 507.8 253.5 514.8 240.9 510.9C228.2 506.1 221.1 493.5 225.1 480.9L369.1 16.89C373 4.226 386.5-2.852 399.1 1.077C411.8 5.006 418.9 18.45 414.9 31.11V31.11zM504.4 118.5L632.4 238.5C637.3 243 640 249.4 640 255.1C640 262.6 637.3 268.1 632.4 273.5L504.4 393.5C494.7 402.6 479.6 402.1 470.5 392.4C461.4 382.7 461.9 367.6 471.6 358.5L580.9 255.1L471.6 153.5C461.9 144.4 461.4 129.3 470.5 119.6C479.6 109.9 494.7 109.4 504.4 118.5V118.5zM168.4 153.5L59.09 255.1L168.4 358.5C178.1 367.6 178.6 382.7 169.5 392.4C160.4 402.1 145.3 402.6 135.6 393.5L7.585 273.5C2.746 268.1 0 262.6 0 255.1C0 249.4 2.746 243 7.585 238.5L135.6 118.5C145.3 109.4 160.4 109.9 169.5 119.6C178.6 129.3 178.1 144.4 168.4 153.5V153.5z"></path></svg>Desarrollo e Ingeniería<svg aria-hidden="true" focusable="false" data-prefix="far" data-icon="chevron-right" class="svg-inline--fa fa-chevron-right ExploreMenu-hover" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 320 512"><path fill="currentColor" d="M113.3 47.41l183.1 191.1c4.469 4.625 6.688 10.62 6.688 16.59s-2.219 11.97-6.688 16.59l-183.1 191.1c-9.152 9.594-24.34 9.906-33.9 .7187c-9.625-9.125-9.938-24.38-.7187-33.91l168-175.4L78.71 80.6c-9.219-9.5-8.906-24.78 .7187-33.91C88.99 37.5 104.2 37.82 113.3 47.41z"></path></svg></span><div class="ExploreMenu-schools" style="background-image:url(https://static.platzi.com/media/uploads/school_graphic_development_3d3b4073cf.png)"><p class="ExploreMenu-title" data-trans="header_explore_exploreMenu_schools">Escuelas<!-- --> <b>5</b></p><ul><li data-testid="school-item"><a href="/escuela/escuela-blockchain/" class="linksTinyBird" data-id="8396" data-page="explorer_desktop_school">Blockchain y Criptomonedas<!-- --> <svg aria-hidden="true" focusable="false" data-prefix="far" data-icon="chevron-right" class="svg-inline--fa fa-chevron-right ExploreMenu-hover" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 320 512"><path fill="currentColor" d="M113.3 47.41l183.1 191.1c4.469 4.625 6.688 10.62 6.688 16.59s-2.219 11.97-6.688 16.59l-183.1 191.1c-9.152 9.594-24.34 9.906-33.9 .7187c-9.625-9.125-9.938-24.38-.7187-33.91l168-175.4L78.71 80.6c-9.219-9.5-8.906-24.78 .7187-33.91C88.99 37.5 104.2 37.82 113.3 47.41z"></path></svg></a><div class="ExploreMenu-routes"><p class="ExploreMenu-title" data-trans="header_explore_exploreMenu_routes">Rutas<!-- --> <b>10</b></p><ul><li data-testid="route-item ...
#   position : fixed;
#   top : 0px;
#   width : 100%;
#   z-index : 9999;
# }
# .PromoBanner.sticky-navidad + .modern-hero, .PromoBanner.sticky-navidad + .Hero {
#   margin-top : 68px;
# }
# .SpecialEventHero-title {
#   color : rgb(39, 39, 39);
# }
# .SpecialEventHero-description {
#   color : rgb(39, 39, 39);
# }
# .SpecialEventHero {
#   align-items : flex-start;
#   background-color : rgb(253, 183, 1);
# }
# .SpecialEventHero-ctaTitle {
#   color : rgb(39, 39, 39);
# }
# .SpecialEventHero-ctaBtn {
#   color : rgb(253, 183, 1);
#   border-color : rgb(39, 39, 39);
#   background-color : rgb(39, 39, 39) !important;
# }
# .SpecialEventHero-ctaBtn--Secondary {
#   border : 1px solid rgb(39, 39, 39);
#   color : rgb(39, 39, 39);
#   background-color : rgb(253, 183, 1) !important;
# }
# @media screen and (max-width: 1024px) {
#   .PromoBanner.sticky-navidad + .modern-hero, .PromoBanner.sticky-navidad + .Hero {
#     margin-top : 58px;
#   }
# }
# @media screen and (max-width: 768px) {
#   .PromoBanner.sticky-navidad + .modern-hero, .PromoBanner.sticky-navidad + .Hero {
#     margin-top : 78px;
#   }
#   .SpecialEventHero-title {
#     margin-bottom : 0px;
#   }
#   .SpecialEventHero {
#     background-position : center top;
#   }
# }
# @media screen and (max-width: 767px) {
#   .SpecialEventHero {
#     background-image : url("");
#   }
# }</style></section><section class="TrustedList"><div class="u-wrapper"><h2 class="TrustedList-description">Empresas y gobiernos que confían en Platzi</h2><ul class="TrustedList-list"><li class="TrustedList-list-item"><div class="TrustedList-logo1"></div></li><li class="TrustedList-list-item"><div class="TrustedList-logo2"></div></li><li class="TrustedList-list-item"><div class="TrustedList-logo3"></div></li><li class="TrustedList-list-item"><div class="TrustedList-logo4"></div></li><li class="TrustedList-list-item"><div class="TrustedList-logo5"></div></li><li class="TrustedList-list-item"><div class="TrustedList-logo6"></div></li><li class="TrustedList-list-item"><div class="TrustedList-logo7"></div></li></ul></div></section><section class="Schools"><div class="u-wrapper"><h2 class="SectionHeading-text SectionHeading-text--is-center">Tú decides a dónde quieres llegar</h2><p class="Schools-description">Especialízate en las áreas con mayor demanda laboral y aprende lo que necesitas para desarrollar tu perfil profesional</p><aside class="SchoolsList-content" data-testid="SchoolsList-content"><a href="/escuela/escuela-web/" target="_blank" class="SchoolsList-school" style="background-color:#81D783;background-image:url(https://static.platzi.com/media/learningpath/ghosts/ac7a95f3-5071-4825-95d6-a8ebb83172bf.jpg)"><img src="https://static.platzi.com/cdn-cgi/image/width=1024,quality=50,format=auto/media/learningpath/emblems/d7acb55b-cab5-4025-ad06-1f1164ea2d26.jpg" srcSet="https://static.platzi.com/cdn-cgi/image/width=480,quality=50,format=auto/media/learningpath/emblems/d7acb55b-cab5-4025-ad06-1f1164ea2d26.jpg 480w, https://static.platzi.com/cdn-cgi/image/width=768,quality=50,format=auto/media/learningpath/emblems/d7acb55b-cab5-4025-ad06-1f1164ea2d26.jpg 768w, https://static.platzi.com/cdn-cgi/image/width=1024,quality=50,format=auto/media/learningpath/emblems/d7acb55b-cab5-4025-ad06-1f1164ea2d26.jpg 1024w, https://static.platzi.com/cdn-cgi/image/width=1200,quality=50,format=auto/media/learningpath/emblems/d7acb55b-cab5-4025-ad06-1f1164ea2d26.jpg 1200w" loading="lazy" sizes="50vw" alt="school-emblem" decoding="async" /><p class="SchoolsList-school-description">Escuela de<!-- --> <br /><strong>Desarrollo Web</strong></p></a><a href="/escuela/escuela-marketing/" target="_blank" class="SchoolsList-school" style="background-color:#6CC3EF;background-image:url()"><img src="https://static.platzi.com/cdn-cgi/image/width=1024,quality=50,format=auto/media/learningpath/emblems/4199eb0b-8f12-403b-a2e4-ec9bf2e369db.jpg" srcSet="https://static.platzi.com/cdn-cgi/image/width=480,quality=50,format=auto/media/learningpath/emblems/4199eb0b-8f12-403b-a2e4-ec9bf2e369db.jpg 480w, https://static.platzi.com/cdn-cgi/image/width=768,quality=50,format=auto/media/learningpath/emblems/4199eb0b-8f12-403b-a2e4-ec9bf2e369db.jpg 768w, https://static.platzi.com/cdn-cgi/image/width=1024,quality=50,format=auto/media/learningpath/emblems/4199eb0b-8f12-403b-a2e4-ec9bf2e369db.jpg 1024w, https://static.platzi.com/cdn-cgi/image/width=1200,quality=50,format=auto/media/learningpath/emblems/4199eb0b-8f12-403b-a2e4-ec9bf2e369db.jpg 1200w" loading="lazy" sizes="50vw" alt="school-emblem" decoding="async" /><p class="SchoolsList-school-description">Escuela de<!-- --> <br /><strong>Marketing Digital</strong></p></a><a href="/escuela/escuela-ingles/" target="_blank" class="SchoolsList-school" style="background-color:#ED82C2;background-image:url()"><img src="https://static.platzi.com/cdn-cgi/image/width=1024,quality=50,format=auto/media/learningpath/emblems/2995b045-55c6-4671-b996-b2b3f4e9620e.jpg" srcSet="https://static.platzi.com/cdn-cgi/image/width=480,quality=50,format=auto/media/learningpath/emblems/2995b045-55c6-4671-b996-b2b3f4e9620e.jpg 480w, https://static.platzi.com/cdn-cgi/image/width=768,quality=50,format=auto/media/learningpath/emblems/2995b045-55c6-4671-b996-b2b3f4e9620e.jpg 768w, https://static.platzi.com/cdn-cgi/image/width=1024,quality=50,format=auto/media/learningp ...
# <div id='portal'></div>
# <script id="preloadedState">window.__PRELOADED_STATE__ = {"prizes":[{"year":"2015","data":[{"logo":"YC","text":"home-public.prizes.yc"}]},{"year":"2016","data":[{"logo":"endevor","text":"home-public.prizes.endevor"}]},{"year":"2017","data":[{"logo":"mintic","text":"home-public.prizes.mintic"}]},{"year":"2018","data":[{"logo":"entrepreneur","text":"home-public.prizes.entrepreneur"},{"logo":"bestStartup","text":"home-public.prizes.bestStartup"}]},{"year":"2019","data":[{"logo":"unity","text":"home-public.prizes.unity"},{"logo":"endevor","text":"home-public.prizes.endevorTwo"}]}],"header":{"enableSubscription":true,"menuItems":[{"name":"Cursos","url":"/cursos/"},{"name":"Blog","url":"/blog/"},{"name":"Comunidad","url":"/comunidad/","items":[{"url":"/comunidad/","icon":null,"name":"Comunidad"},{"url":"/discord/","icon":null,"name":"Discord"},{"url":"/eventos/","icon":null,"name":"Eventos"},{"url":"/agenda/","icon":null,"name":"Últimos cursos"},{"url":"/live/","icon":null,"name":"Live"}]},{"name":"TV","url":"/live/"},{"name":"Planes","url":"/precios/"},{"name":"Contáctanos","url":"","type":"contact"}],"loggedMenu":[{"name":"Empleos","icon":"icon-suitecase_B","url":"/empleos/"},{"name":"Obtén 1 mes gratis","icon":"icon-gift_A","type":"referal","url":"/mi-suscripcion/referidos/"},{"name":"Mi Suscripción","icon":"icon-platzi","type":"my_subscription","url":"/mi-suscripcion/"}],"platziDayEnabled":false,"socials":[{"icon":"icon-twt","url":"https://twitter.com/platzi"},{"icon":"icon-youtube-play","url":"https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ"},{"icon":"icon-fcbk","url":"https://facebook.com/platzi"},{"icon":"icon-instagram","url":"https://www.instagram.com/platzi/"}],"official_companies":[{"logo":"https://static.platzi.com/static/images/footer/logo-ibm.png","name":"IBM","url":""},{"logo":"https://static.platzi.com/static/images/footer/logo-unity.png","name":"Unity","url":""}],"organization_id":1,"enableSearch":true,"logo":"https://static.platzi.com/static/images/footer/logo.png","live":{"active":false,"time":"","url":"","title":"","badge":""},"isLogged":false,"specialEventBanner":null,"basicUpgrade":{},"isHispanic":false,"platziDayIsGoingOn":false,"locale_code":"es-CO","enableReferrals":true,"canonical":"https://platzi.com","showBeneficiaryBanner":false,"country_name":"Colombia","ask_billing_data":false,"country_flag":"https://static.platzi.com/media/flags/CO.png","hasSpecialEventHero":null,"awards":[{"logo":"https://static.platzi.com/static/images/footer/yc.png","name":"Y Combinator","url":"https://platzi.com/blog/platzi-y-combinator/"},{"logo":"https://static.platzi.com/static/images/footer/asugsv.png","name":"ASU + GSV Summit","url":"https://platzi.com/blog/platzi-gana-premio-educacion/"}],"showInvitationModal":false,"headerNotification":{},"userInfo":{"paymentSuccessful":false,"points":0,"referalUrl":"","userType":"","isAuthenticated":false,"userId":0,"profileUrl":"","isB2B":false,"plan":"","name":"","subscription_time":"","lastCourse":[],"pricePlan":"","publicName":"","role":"unlogged","username":"","country":"","nextBillingDate":"","isBundleUser":false,"emailNotValidated":false,"phoneNumber":"","learningPathsAllowed":1,"avatar":"https://static.platzi.com/static/website/v2/images/avatar_default.png","email":""},"locale":"es-CO","languages":[{"url":"https://platzi.com.br","lang_name":"Portugués","lang":"pt","flag":"https://static.platzi.com/static/images/flags/brazil.jpg"},{"url":"https://platzi.com","lang_name":"Español","lang":"es","flag":"https://static.platzi.com/static/images/flags/espana.jpg"}],"promo_banner":{"banner_text":"Prepárate para el 2023 con acceso a todos los cursos por 1 año a precio especial.","previous_price":{"flag":"https://static.platzi.com/media/flags/CO.png","price":"$899.000"},"has_pricing":true,"pre_banner_text":"","primary_color":"#FDB701","active":true,"pricing":{"flag":"https://static.platzi.com/media/flags/CO.png","price":"$599.000"},"primary_logo":"","msi_banner":false,"messages":{"Pr ...
# <script id="initialProps">window.initialProps = {}</script>
# <script id="translations">window.translations = {"messages":{"AccountFooter-login":"Inicia tu sesión","AccountFooter-register":"Regístrate","AccountFooter-title-login":"¿Ya tienes una cuenta?","AccountFooter-title-register":"¿Aún no tienes cuenta en Platzi?","Activations.enterprise.cta":"Empresas","CertifiersText":"Certificadores oficiales en tecnologías","EnterYourEmail":"Ingresa tu correo electrónico","FooterChangeLang":"Cambiar idioma","FooterCopyLink":"ingrese un link","FooterShareLink":"Comparte este link y por cada registro con esta URL te damos un mes","FooterfollowUs":"Aprende en nuestras redes:","LoginSocial-facebook-login":"Inicia sesión con Facebook","LoginSocial-facebook-register":" Regístrate con Facebook","LoginSocial-twitter-login":"Inicia sesión con Twitter","LoginSocial-twitter-register":"Regístrate con Twitter","LoginWithEmail-login":"Inicia sesión","LoginWithEmail-lostpassword":"¿Olvidaste tu contraseña?","PromoBanner.cta":"regístrate","RegisterButton-email":"Regístrate con tu Email","SubscribeSectionCTA":"Suscríbete","SubscribeSectionTitle":"Entérate de todas las novedades en educación, negocios y tecnología","YourEmail":"Correo electrónico","all_courses":"Ver todos mis cursos","avanced_search":"Presiona ENTER para una busqueda avanzada","awardsText":"Reconocidos y premiados por","before":"Antes","billing.address":"* Dirección","billing.city":"* Ciudad","billing.company":"Empresa","billing.company.name":"* Razón Social","billing.cta.save":"GUARDAR DATOS","billing.email":"* Correo electrónico","billing.id.name":"* Número de documento","billing.id.number":"* Número de documento","billing.id.type":"* Tipo de documento","billing.indentity":"Identificación","billing.missing-fields.error":"Hay datos requeridos sin llenar","billing.missing-fields.warning":"* Datos requeridos","billing.person":"Persona Natural","billing.person.name":"* Nombre","billing.person.surname":"* Apellido","billing.state":"* Estado / Departamento","billing.subtitle":"Información obligatoria unicamente para tus facturas. Resolución 30 de 2019 título II Artículo 2 (la siguiente información no podrá ser cambiada).","billing.title":"Ingresar datos de facturación","billing.ubication":"Ubicación","contactus_subtitle":"Elige el medio que más te convenga, te sugerimos ","contactus_title":"¿Tienes dudas o quieres comunicarte con nosotros?","continue_watching":"Continua viendo","countdown_text":"termina en:","countdown_text_pre":"comienza en:","courses":"Cursos","dm":"Mensaje Directo","fromLatam":"De LATAM con ","header.beneficiaryReminder.cta":"Agrega tu beneficiario","header.beneficiaryReminder.text":"Con tu suscripción Expert Duo puedes agregar una persona como beneficiario. Tendrá un plan Expert con su propia cuenta, diplomas de certificación y proceso de aprendizaje.","header.billingReminder.cta":"Completar Formulario","header.billingReminder.text":"Ponte al día con tus obligaciones tributarias actualizando la información para generar tu Factura Electrónica de forma fácil.","header.checkoutSuccess.copy":"La siguiente fecha de renovación sera el \u003cstrong>{{date}}\u003c/strong> por \u003cstrong>{{price}}\u003c/strong>. {{recurrency}}","header.checkoutSuccess.recurrency-annual":"Tu suscripción se renovará automáticamente cada año hasta que se suspenda.","header.checkoutSuccess.recurrency-monthly":"Tu suscripción se renovará automáticamente cada mes hasta que se suspenda.","header.checkoutSuccess.title":"¡Disfruta tu suscripción {{plan}}!","header.invitationModal.description":"Antes de tomar tu primera clase","header.invitationModal.emailInputLabel":"Correo Electrónico","header.invitationModal.emailInputPlaceholder":"Escribe el correo de tu amig@","header.invitationModal.info":"Para que tu cuenta siga activa, estos correos electrónicos deben ser reales y ser verificados.","header.invitationModal.nameInputLabel":"Nombre Completo","header.invitationModal.nameInputPlaceholder":"Escribe el nombre de tu amig@","header.invitationModal.socialTitle":"Co ...
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[7256,5045,5217,9479,1162,7370,5205,9214,5785,4069,8683,9928,2622]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["app-shared-TrustedList-TrustedList-jsx","components-Schools-Schools-jsx","components-RecentLaunches-RecentLaunches-jsx","app-shared-LearningExperience-LearningExperience-jsx","app-shared-Community-Community-jsx","app-shared-Testimonies-Testimonies-jsx","components-B2B-B2B-jsx","components-Prizes-Prizes-jsx","components-NeverStop-NeverStop-jsx"]}</script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/5914.08727fd04f3ce820f757.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/2736.121cb7b1d4dadc257b35.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/9006.d6b90665fa5bb14bf76e.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/2771.fa244f37004f7935ed35.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/4851.f415106c624c2d2697db.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/9264.5c5e475a48b5c5daae60.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/4514.99ed71f7aa9fcbbef26a.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/1904.9e7e3f9d4a21fc3cb296.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/3376.97be01db325b119bf204.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/6066.9c482c6542891d25f689.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/7199.67f933942d6a46c00755.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/6838.33d3972156d8d6d96f24.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/69.115d87bbf9e4c2738bac.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/437.5deed1f8984690a0d381.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/6443.569b253c0f5aa6179b6f.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/3935.e0b0ccd8ee1da552619e.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/381.4ef24135b42d92ef85ca.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/6059.86fe8a09fabd86c36a5f.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/3042.c26f041774ec5045a529.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/940.a9aa4c36abcecfb3ac50.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/8136.dad225d3457d26cb4ed4.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/8876.3587e32a1d8dbbb4d2d0.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/5175.c232666172c2c9227ad1.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/3272.b447fff4c2a9e0fcdc2b.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/1052.ac30de87f1a4c4ff15f8.js"></script>
# <script async data-chunk="home-public-old" src="https://static.platzi.com/mf-landings/assets/home-public-old.903881f15b9cd73fe029.js"></script>
# <script async data-chunk="app-shared-TrustedList-TrustedList-jsx" src="https://static.platzi.com/mf-landings/assets/app-shared-TrustedList-TrustedList-jsx.4dee1c24761c453c73e6.js"></script>
# <script async data-chunk="components-Schools-Schools-jsx" src="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.d5447e3c11674899c980.js"></script>
# <script async data-chunk="components-RecentLaunches-RecentLaunches-jsx" src="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.f1ccb29ab10614903053.js"></script>
# <script async data-chunk="app-shared-LearningExperience-LearningExperience-jsx" src="https://static.platzi.com/mf-landings/assets/app-shared-LearningExperience-LearningExperience-jsx.a540d18ef680190a5759.js"></script>
# <script async data-chunk="app-shared-Community-Community-jsx" src="https://static.platzi.com/mf-landings/assets/app-shared-Community-Community-jsx.3d3ac6a4825db1a75f83.js"></script>
# <script async data-chunk="app-shared-Testimonies-Testimonies-jsx" src="https://static.platzi.com/mf-landings/assets/7370.6988550dc30c2b988a89.js"></script>
# <script async data-chunk="app-shared-Testimonies-Testimonies-jsx" src="https://static.platzi.com/mf-landings/assets/app-shared-Testimonies-Testimonies-jsx.f1121ee9fe6078eebc84.js"></script>
# <script async data-chunk="components-B2B-B2B-jsx" src="https://static.platzi.com/mf-landings/assets/9214.462d89b7ee3e119a9881.js"></script>
# <script async data-chunk="components-B2B-B2B-jsx" src="https://static.platzi.com/mf-landings/assets/5785.647ab8b01d30fcddab14.js"></script>
# <script async data-chunk="components-B2B-B2B-jsx" src="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.1178d53caeadc5a002a6.js"></script>
# <script async data-chunk="components-Prizes-Prizes-jsx" src="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.72cd01445fdc5f3a2aa2.js"></script>
# <script async data-chunk="components-NeverStop-NeverStop-jsx" src="https://static.platzi.com/mf-landings/assets/9928.919d23f94759053b8e90.js"></script>
# <script async data-chunk="components-NeverStop-NeverStop-jsx" src="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.918cf692b6d83fcf35ea.js"></script>
# <script async type="application/ld+json">
#     {
#       "@context": "http://schema.org",
#       "@type": "Organization",
#       "name": "Platzi",
#       "url": "https://platzi.com/",
#       "description": "Aprende de expertos en programación, diseño, marketing, startups, video y web. Suscríbete hoy.",
#       "foundingDate": "2013-01-01",
#       "founders": [
#         {
#           "@type": "Person",
#           "name": "John Freddy Vega"
#         },
#         {
#           "@type": "Person",
#           "name": "Christian Van Der Henst"
#         }
#       ],
#       "sameAs": [
#         "https://www.facebook.com/platzi/",
#         "https://twitter.com/Platzi",
#         "https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ",
#         "https://www.linkedin.com/school/2822346"
#       ]
#     }
#   </script>
# </body>
# </html>
